# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# Check python version

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# **Python Indentation**</br>
# Python uses indentation to indicate a block of code

# %%
if 5 < 7:
  print("5 is less than 7")
# Out:
# 5 is less than 7

# %% [markdown]
# **Python Variables**</br>
# variables are created when you assign values to it

# %%
x = 178
y = "KNUST"

print(x)
print(y)
# Out:
# 178
# KNUST

# %%
# This is a comment
# Comments are not regarded as codes and won't be executed
